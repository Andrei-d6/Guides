# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon_data.csv')

# df_xlsx = pd.read_excel('pokemon_data.xlsx')

# df = pd.read_csv('pokemon_data.txt', delimiter='\t')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df['Name'][:5]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %% [markdown]
# # Reading Data in Pandas

# %%
df.columns  # Read headers
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name', 'Type 1', 'HP']][:5]  # Read specified columns
# Out:
#                     Name Type 1  HP
# 0              Bulbasaur  Grass  45
# 1                Ivysaur  Grass  60
# 2               Venusaur  Grass  80
# 3  VenusaurMega Venusaur  Grass  80
# 4             Charmander   Fire  39

# %%
# Read rows
for index, row in df.iterrows():
    print(index, row['Name'])
    
    if index == 4:
        break
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander

# %%
df['Type 1'] == 'Fire'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799     True
# Name: Type 1, Length: 800, dtype: bool

# %%
df.loc[df['Type 1'] == 'Fire'][:5]  # Access a group of rows and columns by label(s) or boolean array
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
row, column = 2, 2

# Read specific row and column
df.iloc[row, 1]
# Out:
# 'Venusaur'

# %% [markdown]
# # Sorting the Data

# %%
df['HP'][:5]
# Out:
# 0    45
# 1    60
# 2    80
# 3    80
# 4    39
# Name: HP, dtype: int64

# %%
df['HP'][:5].median()
# Out:
# 60.0

# %%
df.sort_values(['Attack', 'Defense'], ascending=[1, 0])[:5]
# Out:
#        #      Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  113   Chansey  Normal    NaN  250       5        5       35      105
# 488  440   Happiny  Normal    NaN  100       5        5       15       65
# 230  213   Shuckle     Bug   Rock   20      10      230       10      230
# 139  129  Magikarp   Water    NaN   20      10       55       15       20
# 261  242   Blissey  Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# 121     50           1      False
# 488     30           4      False
# 230      5           2      False
# 139     80           1      False
# 261     55           2      False

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
45+49+49+65+65+45
# Out:
# 318

# %% [markdown]
# # Saving our Data (Exporting into Desired Format)

# %%
# df.to_csv('modified.csv', index=False)

#df.to_excel('modified.xlsx', index=False)

df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# # Filtering Data

# %%
new_df = df.loc[(df['Type 1'] == 'Fire') & (df['HP'] > 20)]

new_df.head()
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 4       50     65           1      False    309
# 5       65     80           1      False    405
# 6       85    100           1      False    534
# 7       85    100           1      False    634
# 8      115    100           1      False    634

# %%
new_df = new_df.reset_index(drop=True)
new_df.head()
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  4                 Charmander   Fire     NaN  39      52       43       60
# 1  5                 Charmeleon   Fire     NaN  58      64       58       80
# 2  6                  Charizard   Fire  Flying  78      84       78      109
# 3  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 4  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       50     65           1      False    309
# 1       65     80           1      False    405
# 2       85    100           1      False    534
# 3       85    100           1      False    634
# 4      115    100           1      False    634

# %% [markdown]
# # Aggregate Statistics (Groupby)

# %%
df = pd.read_csv('modified.txt', delimiter='\t')
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df['count'] = 1
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total  count
# 0       65     45           1      False    318      1
# 1       80     60           1      False    405      1
# 2      100     80           1      False    525      1
# 3      120     80           1      False    625      1
# 4       50     65           1      False    309      1

# %%
df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# # Working with large amounts of data

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('modified.txt', delimiter='\t', chunksize=5):
    results = df.groupby(['Type 1']).count()
    
    new_df = pd.concat([new_df, results])
